# %%
import cv2
import time 

from matplotlib import pyplot as plt

from config.config import TASK_CONFIG, ROBOT_PORTS

# %%
def capture_and_save_image():
    # Initialize the camera (0 is the default camera)
    cam = cv2.VideoCapture(-1)
    # cam.set(cv2.CAP_PROP_AUTOFOCUS, 1)
    # cam.set(cv2.CAP_PROP_FOCUS, 3)

    # Check if the camera opened successfully
    if not cam.isOpened():
        raise IOError("Cannot open camera")

    for i in range(1):
        t0 = time.time()
        # Capture a single frame
        _, frame = cam.read()
        

        # Generate a unique filename with the current date and time
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        #image = cv2.resize(image, (640, 480), interpolation=cv2.INTER_AREA)
        # Define your crop coordinates (top left corner and bottom right corner)
        # x1, y1 = 400, 000  # Example starting coordinates (top left of the crop rectangle)
        # x2, y2 = 1600, 900  # Example ending coordinates (bottom right of the crop rectangle)

        # Crxp the image
        # image = image[y1:y2, x1:x2]

        image = cv2.resize(image, (640, 480), interpolation=cv2.INTER_AREA)
        print("Time taken to capture image: {:.4f} seconds".format(time.time() - t0))

        print(image.shape)
        # Save the captured image to the current directory
        plt.imshow(image)
        time.sleep(0.04)


    # Release the camera
    cam.release()

# %%
capture_and_save_image()
# Out:
# Time taken to capture image: 0.3030 seconds
# (480, 640, 3)

# %%
cam = cv2.VideoCapture(TASK_CONFIG['camera_port'])

# %%
# init follower
from robot import Robot


follower = Robot(device_name=ROBOT_PORTS['follower'], servo_ids=[1,2,3,4,5,6])
# init leader
leader = Robot(device_name=ROBOT_PORTS['leader'], servo_ids=[1,2,3,4,5,6])
# get bias
# get_bias();exit()
# Out:
# disabling torque for servos [1, 2, 3, 4, 5, 6]

# %%
leader._disable_torque()
follower._disable_torque()
# Out:
# disabling torque for servos [1, 2, 3, 4, 5, 6]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 leader._disable_torque()
#       2 follower._disable_torque()
#
# File ~/code/ACT/robot.py:144, in Robot._disable_torque(self)
#     142 print(f'disabling torque for servos {self.servo_ids}')
#     143 for motor_id in self.servo_ids:
# --> 144     self.dynamixel._disable_torque(motor_id)
#
# File ~/code/ACT/dynamixel.py:177, in Dynamixel._disable_torque(self, motor_id)
#     176 def _disable_torque(self, motor_id):
# --> 177     dxl_comm_result, dxl_error = self.packetHandler.write1ByteTxRx(self.portHandler, motor_id,
#     178                                                                    self.ADDR_TORQUE_ENABLE, 0)
#     179     self._process_response(dxl_comm_result, dxl_error, motor_id)
#     180     self.torque_enabled[motor_id] = False
#
# File ~/miniconda3/envs/robot/lib/python3.10/site-packages/dynamixel_sdk/protocol2_packet_handler.py:653, in Protocol2PacketHandler.write1ByteTxRx(self, port, dxl_id, address, data)
#     651 def write1ByteTxRx(self, port, dxl_id, address, data):
#     652     data_write = [data]
# --> 653     return self.writeTxRx(port, dxl_id, address, 1, data_write)
#
# File ~/miniconda3/envs/robot/lib/python3.10/site-packages/dynamixel_sdk/protocol2_packet_handler.py:643, in Protocol2PacketHandler.writeTxRx(self, port, dxl_id, address, length, data)
#     640 txpacket[PKT_PARAMETER0 + 1] = DXL_HIBYTE(address)
#     642 txpacket[PKT_PARAMETER0 + 2: PKT_PARAMETER0 + 2 + length] = data[0: length]
# --> 643 rxpacket, result, error = self.txRxPacket(port, txpacket)
#     645 return result, error
#
# File ~/miniconda3/envs/robot/lib/python3.10/site-packages/dynamixel_sdk/protocol2_packet_handler.py:323, in Protocol2PacketHandler.txRxPacket(self, port, txpacket)
#     320 error = 0
#     322 # tx packet
# --> 323 result = self.txPacket(port, txpacket)
#     324 if result != COMM_SUCCESS:
#     325     return rxpacket, result, error
#
# File ~/miniconda3/envs/robot/lib/python3.10/site-packages/dynamixel_sdk/protocol2_packet_handler.py:241, in Protocol2PacketHandler.txPacket(self, port, txpacket)
#     238 txpacket[total_packet_length - 1] = DXL_HIBYTE(crc)
#     240 # tx packet
# --> 241 port.clearPort()
#     242 written_packet_length = port.writePort(txpacket)
#     243 if total_packet_length != written_packet_length:
#
# File ~/miniconda3/envs/robot/lib/python3.10/site-packages/dynamixel_sdk/port_handler.py:51, in PortHandler.clearPort(self)
#      50 def clearPort(self):
# ---> 51     self.ser.flush()
#
# File ~/miniconda3/envs/robot/lib/python3.10/site-packages/serial/serialposix.py:673, in Serial.flush(self)
#     671 if not self.is_open:
#     672     raise PortNotOpenError()
# --> 673 termios.tcdrain(self.fd)
#
# error: (6, 'Device not configured')
